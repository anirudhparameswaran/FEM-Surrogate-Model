# %%
import pandas as pd

# %%
df = pd.read_csv('design_out.csv')
df_in = df[['f_mem','sigma_mem', 'E_mem', 'nu_mem', 'sigma_edg', 'sigma_sup', 'sigma_mem_max']]
df_in.head()
# Out:
#       f_mem    sigma_mem          E_mem    nu_mem      sigma_edg  \
# 0  0.268767  3220.880252  620830.965150  0.399472  325851.235578
# 1  0.511186  4603.969420  559505.773241  0.398297  266690.745363
# 2  0.316207  4020.464157  664063.602748  0.393333  350103.330214
# 3  0.457326  4282.802400  622714.404090  0.411230  313489.897816
# 4  0.261861  4097.033516  623600.545225  0.382459  334400.590712
#
#        sigma_sup  sigma_mem_max
# 0  322000.762345    4204.095289
# 1  366814.407254    5578.199692
# 2  308367.205040    4688.809620
# 3  327438.702828    5219.281260
# 4  474471.127871    4986.756515
